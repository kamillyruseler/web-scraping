# %% [markdown]
# <a href="https://colab.research.google.com/github/kamillyruseler/web-scraping/blob/main/Raspagem_dep_federais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deputados Federais

# %%
# @title Página HTML
pagina_html_federais ="""<div><div class="styles__Tag-sc-1kqcjew-0 styles__TagStyled-sc-1kqcjew-1 jizfvP fhItmR container"><div class="styles__Tag-sc-1kqcjew-0 styles__TagStyled-sc-1kqcjew-1 jizfvP fhItmR row"><div class="styles__Tag-sc-1kqcjew-0 styles__TagStyled-sc-1kqcjew-1 jizfvP fhItmR col-12"><div class="container"><div class="row"><div class="col-12"><div class="listaApuracaoStyled__ContainerListagemApuracaoStyled-kmybpi-0 iaoNcP container-listagem-apuracao"><div class="header-listagem-apuracao"><div class="container-type-apuracao"><strong>Deputado Federal</strong><a href="https://www.estadao.com.br/politica/eleicoes/2022/apuracao/primeiro-turno/sc/">Veja a apuração completa <svg viewBox="-6 0 24 24" height="10" width="10" style="margin: 0px; transition: all 0.2s ease 0s; transform: rotate(180deg);"><path fill-rule="evenodd" clip-rule="evenodd" fill="white" d="M0,0H15.052V3.01H0Z" transform="matrix(0.62, 0.785, -0.784, 0.62, 2.36, 10.318)"></path><path fill-rule="evenodd" clip-rule="evenodd" fill="white" d="M0,3.01H15.052V0H0Z" transform="matrix(0.62, -0.785, 0.784, 0.62, 0, 11.815)"></path></svg></a></div><hr><div><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div> Eleito</span><span><svg viewBox="0 0 14.33 14.144" width="10" height="10" cursor="pointer" class="CloseIcon__Container-k4lrle-0 cmuzGk"><path fill-rule="evenodd" clip-rule="evenodd" fill="#f02d1c" d="M0,12.728l5.75-5.75L.186,1.415,1.6,0,7.164,5.563,12.728,0l1.413,1.416L8.579,6.978l5.751,5.751-1.416,1.413-5.75-5.75L1.413,14.144Z"></path></svg> Inapto a assumir</span></div></div><div class="content-listagem-apuracao"><div class="left-content"><div class="filter-listagem-apuracao"><div class="filters-listagem"><div class="container-order-candidates"><span>Ordenar por</span><select placeholder="Mais votados"><option value="DESC">Mais votados</option><option value="ASC">Menos votados</option></select></div><div class="input-search-candidate"><input type="text" placeholder="Buscar por nome"></div></div></div><div class="listagem"><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/carol-de-toni/2200/" title="Carol De Toni"><span>01</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Carol De Toni</span></a><span>5,72%</span></div><div class="informs"><div><span>Nº <strong>2200</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PL</strong></span></div><div><span>Coligação <strong>PL</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>227.632</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/professor-pedro-uczai/1350/" title="Professor Pedro Uczai"><span>02</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Professor Pedro Uczai</span></a><span>4,36%</span></div><div class="informs"><div><span>Nº <strong>1350</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PT</strong></span></div><div><span>Coligação <strong>PC do B / PT / PV</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>173.531</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/jorge-goetten/2222/" title="Jorge Goetten"><span>03</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Jorge Goetten</span></a><span>4,01%</span></div><div class="informs"><div><span>Nº <strong>2222</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PL</strong></span></div><div><span>Coligação <strong>PL</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>159.339</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/ana-paula-lima/1313/" title="Ana Paula Lima"><span>04</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Ana Paula Lima</span></a><span>3,74%</span></div><div class="informs"><div><span>Nº <strong>1313</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PT</strong></span></div><div><span>Coligação <strong>PC do B / PT / PV</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>148.781</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/carmen-zanotto/2323/" title="Carmen Zanotto"><span>05</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Carmen Zanotto</span></a><span>3,27%</span></div><div class="informs"><div><span>Nº <strong>2323</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>CIDADANIA</strong></span></div><div><span>Coligação <strong>CIDADANIA / PSDB</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>130.138</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/julia-zanatta/2233/" title="Julia Zanatta"><span>06</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Julia Zanatta</span></a><span>2,81%</span></div><div class="informs"><div><span>Nº <strong>2233</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PL</strong></span></div><div><span>Coligação <strong>PL</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>111.588</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/ismael/5577/" title="Ismael"><span>07</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Ismael</span></a><span>2,78%</span></div><div class="informs"><div><span>Nº <strong>5577</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PSD</strong></span></div><div><span>Coligação <strong>PSD</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>110.531</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/daniel-freitas/2211/" title="Daniel Freitas"><span>08</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>Daniel Freitas</span></a><span>2,72%</span></div><div class="informs"><div><span>Nº <strong>2211</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PL</strong></span></div><div><span>Coligação <strong>PL</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>108.001</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/cobalchini/1560/" title="Cobalchini"><span>09</span><span><div style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);"></div></span><span>
span></a><span>0%</span></div><div class="informs"><div><span>Nº <strong>9002</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PROS</strong></span></div><div><span>Coligação <strong>PROS</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>94</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/marisa-da-cocada/7001/" title="Marisa Da Cocada"><span>283</span><span>Marisa Da Cocada</span></a><span>0%</span></div><div class="informs"><div><span>Nº <strong>7001</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>AVANTE</strong></span></div><div><span>Coligação <strong>AVANTE</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>92</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/iris-carla/7010/" title="Íris Carla"><span>284</span><span>Íris Carla</span></a><span>0%</span></div><div class="informs"><div><span>Nº <strong>7010</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>AVANTE</strong></span></div><div><span>Coligação <strong>AVANTE</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>64</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/josi-heineck/1454/" title="Josi Heineck"><span>285</span><span>Josi Heineck</span></a><span>0%</span></div><div class="informs"><div><span>Nº <strong>1454</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PTB</strong></span></div><div><span>Coligação <strong>PTB</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>61</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/cris-alves/9005/" title="Cris Alves"><span>286</span><span>Cris Alves</span></a><span>0%</span></div><div class="informs"><div><span>Nº <strong>9005</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PROS</strong></span></div><div><span>Coligação <strong>PROS</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>55</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/paula-marizane/7766/" title="Paula Marizane"><span>287</span><span>Paula Marizane</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>7766</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>SOLIDARIEDADE</strong></span></div><div><span>Coligação <strong>SOLIDARIEDADE</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>39</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/day/7713/" title="Day"><span>288</span><span>Day</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>7713</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>SOLIDARIEDADE</strong></span></div><div><span>Coligação <strong>SOLIDARIEDADE</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>38</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/nara-favero/9004/" title="Nara Favero"><span>289</span><span>Nara Favero</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>9004</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PROS</strong></span></div><div><span>Coligação <strong>PROS</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>37</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/arnaldo-lovatel/7770/" title="Arnaldo Lovatel"><span>290</span><span>Arnaldo Lovatel</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>7770</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>SOLIDARIEDADE</strong></span></div><div><span>Coligação <strong>SOLIDARIEDADE</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>29</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/angelo-weber/9001/" title="Angelo Weber"><span>291</span><span>Angelo Weber</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>9001</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PROS</strong></span></div><div><span>Coligação <strong>PROS</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>29</strong></span></div></div></div><div class="listItem"><div class="header-listItem"><a href="https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/maiara-carvalho/9014/" title="Maiara Carvalho"><span>292</span><span>Maiara Carvalho</span></a><span>0,01%</span></div><div class="informs"><div><span>Nº <strong>9014</strong></span><div class="divisor-coligacao"></div><span>Partido <strong>PROS</strong></span></div><div><span>Coligação <strong>PROS</strong></span><div class="divisor-coligacao"></div><span>Votos <strong>10</strong></span></div></div></div><span>ATUALIZADO EM: 02/10/2022 - 22:34:44 | FONTE: TSE</span></div><button class="buttonLoadItemsStyled__ButtonLoadItemsStyled-sc-1el6mce-0 efxcdM ButtonLoadItems">Carregar mais<svg viewBox="-6 0 24 24" height="15" width="15" style="margin: 0px; transition: all 0.2s ease 0s; transform: rotate(270deg);"><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,0H15.052V3.01H0Z" transform="matrix(0.62, 0.785, -0.784, 0.62, 2.36, 10.318)"></path><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,3.01H15.052V0H0Z" transform="matrix(0.62, -0.785, 0.784, 0.62, 0, 11.815)"></path></svg></button><a href="https://www.estadao.com.br/politica/eleicoes/2022/apuracao/primeiro-turno/sc/">Veja a apuração completa <svg viewBox="-6 0 24 24" height="10" width="10" style="margin: 0px; transition: all 0.2s ease 0s; transform: rotate(180deg);"><path fill-rule="evenodd" clip-rule="evenodd" fill="white" d="M0,0H15.052V3.01H0Z" transform="matrix(0.62, 0.785, -0.784, 0.62, 2.36, 10.318)"></path><path fill-rule="evenodd" clip-rule="evenodd" fill="white" d="M0,3.01H15.052V0H0Z" transform="matrix(0.62, -0.785, 0.784, 0.62, 0, 11.815)"></path></svg></a></div><div class="right-content"><div class="publicidade"><div class="" style="width: 100%; overflow: hidden;"><div class="styles__Container-sc-1v8tg5g-0 iPOcmU" style="width: 100%;"><p class="ads-placeholder-label">Publicidade</p><div class="ads-placeholder-wrapper"><div id="tmeio1-6" class="styles__AdSlotStyled-sc-1l64tzh-0 fOjWcu" data-google-query-id="CO3W_uLL-oADFdZG3QIdrawEkg"><div id="google_ads_iframe_/118650305/politica/noticia_0__container__" style="border: 0pt none;"><iframe id="google_ads_iframe_/118650305/politica/noticia_0" name="google_ads_iframe_/118650305/politica/noticia_0" title="3rd party ad content" width="300" height="250" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" role="region" aria-label="Advertisement" tabindex="0" style="border: 0px; vertical-align: bottom;" data-google-container-id="1" data-load-complete="true"></iframe></div></div></div></div></div></div><div class="votos-por-partido"><div class="content-votos-por-partido"><strong>Votos por partido</strong><div class="partido"><span>PL</span><div class="container-bar"><div class="progressbar" style="width: 24.17%;"></div></div><span>24.17%</span></div><div class="partido"><span>PT</span><div class="container-bar"><div class="progressbar" style="width: 11.52%;"></div></div><span>11.52%</span></div><div class="partido"><span>MDB</span><div class="container-bar"><div class="progressbar" style="width: 10.61%;"></div></div><span>10.61%</span></div><div class="partido"><span>PSD</span><div class="container-bar"><div class="progressbar" style="width: 10.07%;"></div></div><span>10.07%</span></div><div class="partido"><span>UNIÃO</span><div class="container-bar"><div class="progressbar" style="width: 7.15%;"></div></div><span>7.15%</span></div><div class="partido"><span>NOVO</span><div class="container-bar"><div class="progressbar" style="width: 6.17%;"></div></div><span>6.17%</span></div><div class="partido"><span>PP</span><div class="container-bar"><div class="progressbar" style="width: 5.3%;"></div></div><span>5.3%</span></div><div class="partido"><span>PODE</span><div class="container-bar"><div class="progressbar" style="width: 4.76%;"></div></div><span>4.76%</span></div><div class="partido"><span>CIDADANIA</span><div class="container-bar"><div class="progressbar" style="width: 3.56%;"></div></div><span>3.56%</span></div><div class="partido"><span>PSDB</span><div class="container-bar"><div class="progressbar" style="width: 3.5%;"></div></div><span>3.5%</span></div><div class="partido"><span>REPUBLICANOS</span><div class="container-bar"><div class="progressbar" style="width: 3.06%;"></div></div><span>3.06%</span></div><div class="partido"><span>PATRIOTA</span><div class="container-bar"><div class="progressbar" style="width: 1.84%;"></div></div><span>1.84%</span></div></div><span>ATUALIZADO EM: 02/10/2022 - 22:34:44 | FONTE: TSE</span><button class="buttonLoadItemsStyled__ButtonLoadItemsStyled-sc-1el6mce-0 efxcdM ButtonLoadItems">Carregar mais<svg viewBox="-6 0 24 24" height="15" width="15" style="margin: 0px; transition: all 0.2s ease 0s; transform: rotate(270deg);"><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,0H15.052V3.01H0Z" transform="matrix(0.62, 0.785, -0.784, 0.62, 2.36, 10.318)"></path><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,3.01H15.052V0H0Z" transform="matrix(0.62, -0.785, 0.784, 0.62, 0, 11.815)"></path></svg></button></div><div class="coligacao"><div class="content-coligacao"><strong>Vagas por coligação</strong><div><span>PL</span><span>6</span></div><div><span>MDB</span><span>3</span></div><div><span>PC DO B / PT / PV</span><span>2</span></div><div><span>PSD</span><span>2</span></div><div><span>CIDADANIA / PSDB</span><span>1</span></div><div><span>NOVO</span><span>1</span></div><div><span>UNIÃO</span><span>1</span></div><div><span>AVANTE</span><span>0</span></div><div><span>DC</span><span>0</span></div><div><span>PATRIOTA</span><span>0</span></div><div><span>PCO</span><span>0</span></div><div><span>PDT</span><span>0</span></div></div><span>ATUALIZADO EM: 02/10/2022 - 22:34:44 | FONTE: TSE</span><button class="buttonLoadItemsStyled__ButtonLoadItemsStyled-sc-1el6mce-0 efxcdM ButtonLoadItems">Carregar mais<svg viewBox="-6 0 24 24" height="15" width="15" style="margin: 0px; transition: all 0.2s ease 0s; transform: rotate(270deg);"><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,0H15.052V3.01H0Z" transform="matrix(0.62, 0.785, -0.784, 0.62, 2.36, 10.318)"></path><path fill-rule="evenodd" clip-rule="evenodd" fill="#2575e8" d="M0,3.01H15.052V0H0Z" transform="matrix(0.62, -0.785, 0.784, 0.62, 0, 11.815)"></path></svg></button></div></div></div></div></div></div></div></div></div></div></div>"""

# %%
#Instalação do unidecode, para remover acentuação em links
# !pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
#Importações das bibliotecas

from bs4 import BeautifulSoup
import re
import pandas as pd
import unidecode
import requests
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
#Configuração do ambiente

soup = BeautifulSoup(pagina_html_federais, 'html.parser')

#O cabeçalho de solicitação do Agente do Usuário é uma string de caracteres que permite que servidores e pares de rede identifiquem
# o aplicativo, sistema operacional, fornecedor e / ou versão do agente do usuário solicitante.
#Alguns sites exigem o User-Agent de um navegador principal ou então não permitem a visualização do conteúdo.


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# %%
#Para coletar a data das eleições:
span_elements = soup.find_all("span")
last_span = span_elements[-1]
ano = last_span.get_text()
partes = ano.split(" - ")
data_part = partes[0].strip()  # Remove espaços em branco
data = data_part.split(": ")[1]  # Dividir novamente e pegar a parte após ": "
print(data)
# Out:
# 02/10/2022

# %%
candidatos_federais = []
for deputado_federal in soup.find_all("div", attrs={"class": "listItem"}):

##Informações básicas do deputado:
    a = deputado_federal.find("a", attrs={"title": True})
    nome = a.text
    nome_sem_numeros = re.sub(r'\d+', '', nome)  # Remover os números usando expressão regular
    votos = deputado_federal.find_all('strong')[3].text
    numero = deputado_federal.find_all('strong')[0].text
    partido = deputado_federal.find_all('strong')[1].text

##Verificando se foi eleito:
    div_style = deputado_federal.find("div", style="width: 10px; height: 10px; border-radius: 50%; background-color: rgb(37, 117, 232);")
    if div_style:
        status = "Eleito"
    else:
        status = "Não eleito"

##Verificando se está apto
    svg_element = deputado_federal.find("svg", attrs={"class": "CloseIcon__Container-k4lrle-0 cmuzGk"})
    if svg_element and svg_element.find("path", attrs={"fill": "#f02d1c"}):
        aptidao = "Inapto"
    else:
        aptidao = "Apto"

    candidatos_federais.append((nome_sem_numeros, partido, votos, numero, data, status, aptidao))

# %%
candidatos_federais_df = pd.DataFrame(candidatos_federais)
candidatos_federais_df = candidatos_federais_df.rename(columns={0: 'Nome do candidato', 1: 'Partido', 2: 'Quantidade de votos', 3: 'Número do candidato', 4: 'Data da eleição', 5: 'Resultado', 6:'Aptidão'})

# %%
candidatos_federais_df
# Out:
#          Nome do candidato        Partido Quantidade de votos  \
# 0            Carol De Toni             PL             227.632
# 1    Professor Pedro Uczai             PT             173.531
# 2            Jorge Goetten             PL             159.339
# 3           Ana Paula Lima             PT             148.781
# 4           Carmen Zanotto      CIDADANIA             130.138
# ..                     ...            ...                 ...
# 287                    Day  SOLIDARIEDADE                  38
# 288            Nara Favero           PROS                  37
# 289        Arnaldo Lovatel  SOLIDARIEDADE                  29
# 290           Angelo Weber           PROS                  29
# 291        Maiara Carvalho           PROS                  10
#
#     Número do candidato Data da eleição   Resultado Aptidão
# 0                  2200      02/10/2022      Eleito    Apto
# 1                  1350      02/10/2022      Eleito    Apto
# ...

# %%
# Função para criar o link com base nos valores do DataFrame
links = []
def criar_link(row):
    nome_formatado = '-'.join(row['Nome do candidato'].split()).lower()
    nome_formatado = unidecode.unidecode(nome_formatado)
    numero_candidato = row['Número do candidato']
    link = f"https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/{nome_formatado}/{numero_candidato}/"
    return link


# Calcular e mostrar os links sem adicionar ao DataFrame
for index, row in candidatos_federais_df.iterrows():
    link = criar_link(row)
    links.append(link)
    print(link)
# Out:
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/carol-de-toni/2200/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/professor-pedro-uczai/1350/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/jorge-goetten/2222/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/ana-paula-lima/1313/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/carmen-zanotto/2323/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/julia-zanatta/2233/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/ismael/5577/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/daniel-freitas/2211/
# https://www.estadao.com.br/politica/eleicoes/2022/candidatos/sc/deputado-federal/cobalchini/1560/
# ...

# %%
# Fazer uma solicitação HTTP à página do candidato com o cabeçalho do usuário
for idx, link in enumerate(links):
    response = requests.get(link, headers=headers)
    if response.status_code == 200:
        candidato_soup = BeautifulSoup(response.content, 'html.parser')

        # Encontrar todas as ocorrências da div com a classe "profile-infos-value"
        divs_profile_infos = candidato_soup.find_all("div", class_="profile-infos-value")

        # Verificar se existe uma terceira ocorrência
        if len(divs_profile_infos) >= 3:
            # Acessar o texto da terceira ocorrência
            naturalidade = divs_profile_infos[7].text.strip()
            #print("Naturalidade:", naturalidade)

            bens = divs_profile_infos[11].text.strip()
            #print("Valor em bens:", bens)

            idade = divs_profile_infos[6].text.strip()
            #print("Idade:", idade[:2])

            educacao = divs_profile_infos[4].text.strip()
            #print("Educação:", educacao)

            ocupacao = divs_profile_infos[5].text.strip()
            #print("Ocupação:", ocupacao)

            # Atualizar os valores nas linhas correspondentes do DataFrame
            candidatos_federais_df.loc[idx, 'Naturalidade'] = naturalidade
            candidatos_federais_df.loc[idx, 'Valor em bens'] = bens
            candidatos_federais_df.loc[idx, 'Idade'] = idade[:2]
            candidatos_federais_df.loc[idx, 'Educação'] = educacao
            candidatos_federais_df.loc[idx, 'Ocupação'] = ocupacao

        else:
            print("Não foi possível encontrar a ocorrência.")
    else:
        print(f"Erro ao acessar: {link}")

# Mostrar o DataFrame resultante
print(candidatos_federais_df)
# Out:
# Não foi possível encontrar a ocorrência.
#          Nome do candidato        Partido Quantidade de votos  \
# 0            Carol De Toni             PL             227.632
# 1    Professor Pedro Uczai             PT             173.531
# 2            Jorge Goetten             PL             159.339
# 3           Ana Paula Lima             PT             148.781
# 4           Carmen Zanotto      CIDADANIA             130.138
# ..                     ...            ...                 ...
# 287                    Day  SOLIDARIEDADE                  38
# 288            Nara Favero           PROS                  37
# 289        Arnaldo Lovatel  SOLIDARIEDADE                  29
# 290           Angelo Weber           PROS                  29
# 291        Maiara Carvalho           PROS                  10
#
#     Número do candidato Data da eleição   Resultado Aptidão      Naturalidade  \
# 0                  2200      02/10/2022      Eleito    Apto           Chapecó
# ...

# %%
candidatos_federais_df.to_csv('candidatos_df.csv', index=False)

# %%
candidatos_federais_df
# Out:
#          Nome do candidato        Partido Quantidade de votos  \
# 0            Carol De Toni             PL             227.632
# 1    Professor Pedro Uczai             PT             173.531
# 2            Jorge Goetten             PL             159.339
# 3           Ana Paula Lima             PT             148.781
# 4           Carmen Zanotto      CIDADANIA             130.138
# ..                     ...            ...                 ...
# 287                    Day  SOLIDARIEDADE                  38
# 288            Nara Favero           PROS                  37
# 289        Arnaldo Lovatel  SOLIDARIEDADE                  29
# 290           Angelo Weber           PROS                  29
# 291        Maiara Carvalho           PROS                  10
#
#     Número do candidato Data da eleição   Resultado Aptidão      Naturalidade  \
# 0                  2200      02/10/2022      Eleito    Apto           Chapecó
# ...

# %%
def convert_valor(valor):
    try:
        return float(re.sub(r'[^\d.]', '', valor))
    except:
        return 0.0

# Aplicar a função de conversão à coluna "Valor em bens"
candidatos_federais_df["Valor em bens"] = candidatos_federais_df["Valor em bens"].apply(convert_valor)

# %%
# Função para converter a quantidade de votos para int
def convert_votos(votos):
    try:
        return int(re.sub(r'\D', '', votos))
    except:
        return 0
candidatos_federais_df["Quantidade de votos"] = candidatos_federais_df["Quantidade de votos"].apply(convert_votos)

# %%
# Criar o gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(candidatos_federais_df["Quantidade de votos"], candidatos_federais_df["Valor em bens"], color='blue')
plt.title("Correlação entre Quantidade de Votos e Valor em Bens")
plt.xlabel("Quantidade de Votos")
plt.ylabel("Valor em Bens (R$)")
plt.grid(True)
plt.show()

# %%
media_votos_por_formacao = candidatos_federais_df.groupby("Educação")["Quantidade de votos"].mean()

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
media_votos_por_formacao.sort_values().plot(kind="bar", color='blue')
plt.title("Média de Quantidade de Votos por Formação")
plt.xlabel("Educação")
plt.ylabel("Média de Votos")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Calcular a média de votos por partido
media_votos_por_partido = candidatos_federais_df.groupby("Partido")["Quantidade de votos"].mean()

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
media_votos_por_partido.sort_values().plot(kind="bar", color='blue')
plt.title("Média de Quantidade de Votos por Partido")
plt.xlabel("Partido")
plt.ylabel("Média de Votos")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Verificar se a coluna "Idade" contém apenas valores numéricos
candidatos_federais_df["Idade"] = pd.to_numeric(candidatos_federais_df["Idade"], errors='coerce')

# Filtrar linhas com valores numéricos na coluna "Idade"
candidatos_federais_df = candidatos_federais_df.dropna(subset=["Idade"])

# %%
# Criar o gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(candidatos_federais_df["Idade"], candidatos_federais_df["Quantidade de votos"], color='blue', alpha=0.5)
plt.title("Relação entre Idade e Quantidade de Votos")
plt.xlabel("Idade")
plt.ylabel("Quantidade de Votos")
plt.grid(True)
plt.show()

# %%
# Agrupar por naturalidade e somar os votos
ranking_naturalidades = candidatos_federais_df.groupby("Naturalidade")["Quantidade de votos"].sum()

# Ordenar o ranking pela quantidade de votos
ranking_naturalidades = ranking_naturalidades.sort_values(ascending=False)

# Criar o gráfico de barras para o ranking de naturalidades
plt.figure(figsize=(12, 6))
ranking_naturalidades.head(10).plot(kind="bar", color='blue')
plt.title("Ranking de Naturalidades com Mais Votos")
plt.xlabel("Naturalidade")
plt.ylabel("Total de Votos")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Agrupar por profissão e somar os votos
ranking_profissoes = candidatos_federais_df.groupby("Ocupação")["Quantidade de votos"].sum()

# Ordenar o ranking pela quantidade de votos
ranking_profissoes = ranking_profissoes.sort_values(ascending=False)

# Criar o gráfico de barras para o ranking de profissões
plt.figure(figsize=(12, 6))
ranking_profissoes.head(10).plot(kind="bar", color='blue')
plt.title("Ranking de Profissões com Mais Votos")
plt.xlabel("Profissão")
plt.ylabel("Total de Votos")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Definir as faixas etárias e rótulos
faixas_etarias = [(18, 25), (26, 35), (36, 45), (46, 55), (56, 65), (66, 100)]
rotulos_faixas = ['18-25', '26-35', '36-45', '46-55', '56-65', '66+']

# Criar uma nova coluna com a faixa etária correspondente
candidatos_federais_df["Faixa Etária"] = pd.cut(candidatos_federais_df["Idade"], bins=[f[0] for f in faixas_etarias] + [faixas_etarias[-1][-1]], labels=rotulos_faixas)

# Agrupar por faixa etária e somar os votos
ranking_faixas_etarias = candidatos_federais_df.groupby("Faixa Etária")["Quantidade de votos"].sum()

# Ordenar o ranking pela quantidade de votos
ranking_faixas_etarias = ranking_faixas_etarias.sort_values(ascending=False)

# Criar o gráfico de barras para o ranking de faixas etárias
plt.figure(figsize=(10, 6))
ranking_faixas_etarias.plot(kind="bar", color='blue')
plt.title("Ranking de Faixas Etárias com Mais Votos")
plt.xlabel("Faixa Etária")
plt.ylabel("Total de Votos")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# <ipython-input-25-681deb04d59b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candidatos_federais_df["Faixa Etária"] = pd.cut(candidatos_federais_df["Idade"], bins=[f[0] for f in faixas_etarias] + [faixas_etarias[-1][-1]], labels=rotulos_faixas)

# %%
# Calcular a média de valores em bens
media_valores_em_bens = candidatos_federais_df["Valor em bens"].mean()

# Adicionar uma coluna indicando se o candidato está acima ou abaixo da média
candidatos_federais_df["Acima da Média"] = candidatos_federais_df["Valor em bens"] > media_valores_em_bens

# Filtrar os candidatos eleitos
candidatos_eleitos = candidatos_federais_df[candidatos_federais_df["Resultado"] == "Eleito"]

# Criar um novo DataFrame com as informações desejadas
resultado_df = candidatos_eleitos[["Nome do candidato", "Valor em bens", "Acima da Média"]]

# Calcular a porcentagem de candidatos eleitos acima da média
porcentagem_acima_media = (resultado_df["Acima da Média"].sum() / len(resultado_df)) * 100

# Imprimir o resultado DataFrame e a porcentagem
print(f"Porcentagem de candidatos eleitos acima da média: {porcentagem_acima_media:.2f}%")
# Out:
# Porcentagem de candidatos eleitos acima da média: 31.25%
# <ipython-input-26-673d5b2c5b95>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candidatos_federais_df["Acima da Média"] = candidatos_federais_df["Valor em bens"] > media_valores_em_bens

# %%
resultado_df
# Out:
#         Nome do candidato  Valor em bens  Acima da Média
# 0           Carol De Toni        651.781            True
# 1   Professor Pedro Uczai          0.000           False
# 2           Jorge Goetten          0.000           False
# 3          Ana Paula Lima          0.000           False
# 4          Carmen Zanotto        304.763            True
# 5           Julia Zanatta          0.000           False
# 6                  Ismael        562.162            True
# 7          Daniel Freitas        421.194            True
# 8              Cobalchini          0.000           False
# 9          Gilson Marques          0.000           False
# 10        Daniela Reinehr         62.290           False
# 11        Carlos Chiodini          0.000           False
# 12          Ricardo Guidi          0.000           False
# 13              Zé Trovão          0.000           False
# 14         Rafael Pezenti        455.977            True
# ...

# %%
# Calcular a quantidade de valores em bens zerados e acima de zero
quantidade_bens_zerados = (candidatos_federais_df["Valor em bens"] == 0).sum()
quantidade_bens_acima_zero = (candidatos_federais_df["Valor em bens"] > 0).sum()

# Calcular as porcentagens
porcentagem_bens_zerados = (quantidade_bens_zerados / len(candidatos_federais_df)) * 100
porcentagem_bens_acima_zero = (quantidade_bens_acima_zero / len(candidatos_federais_df)) * 100

# Criar um DataFrame com os resultados
resultado_porcentagem_df = pd.DataFrame({
    "Categoria": ["Bens Zerados", "Bens Acima de Zero"],
    "Quantidade": [quantidade_bens_zerados, quantidade_bens_acima_zero],
    "Porcentagem": [porcentagem_bens_zerados, porcentagem_bens_acima_zero]
})

# %%
resultado_porcentagem_df
# Out:
#             Categoria  Quantidade  Porcentagem
# 0        Bens Zerados         131    45.017182
# 1  Bens Acima de Zero         160    54.982818

# %%
# Calcular a quantidade de bens zerados por partido
bens_zerados_por_partido = candidatos_federais_df[candidatos_federais_df["Valor em bens"] == 0].groupby("Partido").size().reset_index(name="Quantidade Bens Zerados")

# Ordenar o DataFrame por quantidade de bens zerados
bens_zerados_por_partido = bens_zerados_por_partido.sort_values(by="Quantidade Bens Zerados", ascending=False)

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(bens_zerados_por_partido["Partido"], bens_zerados_por_partido["Quantidade Bens Zerados"], color='blue')
plt.title("Quantidade de Bens Zerados por Partido")
plt.xlabel("Partido")
plt.ylabel("Quantidade de Bens Zerados")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
candidatos_federais_df
# Out:
#          Nome do candidato        Partido  Quantidade de votos  \
# 0            Carol De Toni             PL               227632
# 1    Professor Pedro Uczai             PT               173531
# 2            Jorge Goetten             PL               159339
# 3           Ana Paula Lima             PT               148781
# 4           Carmen Zanotto      CIDADANIA               130138
# ..                     ...            ...                  ...
# 287                    Day  SOLIDARIEDADE                   38
# 288            Nara Favero           PROS                   37
# 289        Arnaldo Lovatel  SOLIDARIEDADE                   29
# 290           Angelo Weber           PROS                   29
# 291        Maiara Carvalho           PROS                   10
#
#     Número do candidato Data da eleição   Resultado Aptidão      Naturalidade  \
# 0                  2200      02/10/2022      Eleito    Apto           Chapecó
# ...

# %%
# Exportar o DataFrame para um arquivo JSON com codificação UTF-8
with open("candidatos.json", "w", encoding="utf-8") as json_file:
    json.dump(candidatos_federais_df.to_dict(orient="records"), json_file, ensure_ascii=False, indent=4)
